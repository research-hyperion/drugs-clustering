# %%
import xml.etree.ElementTree as ET
import csv

# %%
class Database:
    def __init__(self, filename:str):
        self.__filename = filename
    
    def parse(self):
        tree = ET.parse(self.__filename)
        self.__xml_root = tree.getroot()
        
    def get_number_of_interactions(self,drug_name:str)->int:        
        results=self.__xml_root.findall("./{http://www.drugbank.ca}drug/[{http://www.drugbank.ca}name='%s']/{http://www.drugbank.ca}drug-interactions/{http://www.drugbank.ca}drug-interaction/{http://www.drugbank.ca}name" % drug_name)
        return len(results)
    
    def get_group(self,drug_name:str)->str:
        group = self.__xml_root.findall("./{http://www.drugbank.ca}drug/[{http://www.drugbank.ca}name='%s']/{http://www.drugbank.ca}groups/{http://www.drugbank.ca}group" % drug_name)    
        return group

# %%
DRUGBANK_DATABASES:list() = [
    (0,"DB 3.0","database/3.0/drugbank.xml",2013),
    (1,"DB 4.1","database/4.1/drugbank.xml",2014), #not sure about year
    (2,"DB 4.2","database/4.2/drugbank.xml",2015), #not sure about year
    (3,"DB 4.3","database/4.3/drugbank.xml",2015),
    (4,"DB 4.5","database/4.5.0/drugbank.xml",2016),
    (5," DB 5.0","database/5.0.0/drugbank.xml",2016),
    (6,"DB 5.0.1","database/5.0.1/drugbank.xml",2016),
    (7,"DB 5.0.2","database/5.0.2/drugbank.xml",2016),
    (8,"DB 5.0.3","database/5.0.3/drugbank.xml",2016),
    (9,"DB 5.0.4","database/5.0.4/full_database.xml",2017),
    (10,"DB 5.0.5","database/5.0.5/full_database.xml",2017),
    (11,"DB 5.0.6","database/5.0.6/full_database.xml",2017),
    (12,"DB 5.0.7","database/5.0.7/full_database.xml",2017),
    (13,"DB 5.0.8","database/5.0.8/full_database.xml",2017),
    (14,"DB 5.0.9","database/5.0.9/full_database.xml",2017), 
    (15,"DB 5.0.10","database/5.0.10/full_database.xml",2017),
    (16,"DB 5.0.11","database/5.0.11/full_database.xml",2017),
    (17,"DB 5.1.0","database/5.1.0/full_database.xml",2018),
    (18,"DB 5.1.1","database/5.1.1/full_database.xml",2018),
    (19,"DB 5.1.2","database/5.1.2/full_database.xml",2018),
    (20,"DB 5.1.3","database/5.1.3/full_database.xml",2019),
    (21,"DB 5.1.4","database/5.1.4/full_database.xml",2019),
    (22,"DB 5.1.5","database/5.1.5/full_database.xml",2020),
    (23,"DB 5.1.6","database/5.1.6/full_database.xml",2020),
    (24,"DB 5.1.7","database/5.1.7/full_database.xml",2020),
    (25,"DB 5.1.8","database/5.1.8/full_database.xml",2021)
]

# %%
CSV_DRUG_AGE_FILE_INPUT:str = "Drugs_age_bibliography.csv"
CSV_DRUG_AGE_FILE_OUTPUT:str = "drugs_age_interactions.csv"

# %%
def read_csv(file:str)->list():
    values = []
    labels = []
    data_list = list()
    with open(file, encoding='utf-8-sig') as csv_file:
        
        reader = csv.DictReader(csv_file, delimiter=',')
        
        for row in reader:
            #print(row['label'], row["approval date (year, first country)"], row["age"])
            data_list.append((row['id'],row['label'], row["approval date (year, first country)"], row["age"]))
    return data_list

# %%
def write_csv(file, data):
    with open(file,mode='w') as output_file:
        output_file_write = csv.writer(output_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        
        csv_labels = ['id','label','approval date (year, first country)','age']
        for db_name in DRUGBANK_DATABASES:
            csv_labels.append(db_name[1])
        output_file_write.writerow(csv_labels)
        for item in data:
            #(id,labe,approval date, age, [])
            data_row = [item[0],item[1],item[2],item[3]]
            for interaction in item[4]:
                data_row.append(interaction)
            output_file_write.writerow(data_row)

# %%
output_data = list()
drugs_list = read_csv(CSV_DRUG_AGE_FILE_INPUT)
for drug in drugs_list:
    output_data.append((drug[0],drug[1],drug[2],drug[3],list()))

# %%
output_data
# Out:
# [('7761', 'Levamisole', '1971', '50', []),
#  ('7764', 'Nicotine', '1978', '43', []),
#  ('7765', 'Cevimeline', '2000', '21', []),
#  ('7767', 'Succinylcholine', '1952', '69', []),
#  ('7774', 'Carbachol', '1951', '70', []),
#  ('7795', 'Bethanechol', '1948', '73', []),
#  ('7798', 'Pilocarpine', '1877', '144', []),
#  ('7801', 'Ambenonium', '1950', '71', []),
#  ('7807', 'Decamethonium', '1949', '72', []),
#  ('7808', 'Varenicline', '2006', '15', []),
#  ('7824', 'Methacholine', '1986', '35', []),
#  ('7829', 'Cytisine', '1964', '57', []),
#  ('7830', 'Tacrine', '1993', '28', []),
#  ('7831', 'Pyridostigmine', '1955', '66', []),
#  ('7832', 'Galantamine', '2001', '20', []),
#  ('7833', 'Isoflurophate', '1949', '72', []),
#  ('7834', 'Malathion', '1982', '39', []),
#  ('7836', 'Donepezil', '1996', '25', []),
#  ('7838', 'Hexafluronium', '1955', '66', []),
#  ('7839', 'Demecarium', '1959', '62', []),
#  ('7840', 'Physostigmine', '1875', '146', []),
#  ('7841', 'Rivastigmine', '1997', '24', []),
#  ('7842', 'Edrophonium', '1951', '70', []),
#  ('7843', 'Echothiophate', '1959', '62', []),
#  ('7844', 'Neostigmine', '1931', '90', []),
#  ('7846', 'Dimetacrine', '1967', '54', []),
#  ('8109', 'Tubocurarine', '1945', '76', []),
#  ('7876', 'Butabarbital', '1932', '89', []),
#  ('7878', 'Butalbital', '1970', '51', []),
#  ('7895', 'Talbutal', '1955', '66', []),
#  ('7899', 'Pentobarbital', '1930', '91', []),
#  ('7923', 'Secobarbital', '1934', '87', []),
#  ('7931', 'Metharbital', '1948', '73', []),
#  ('7961', 'Thiopental', '1934', '87', []),
#  ('7998', 'Primidone', '1950', '71', []),
#  ('8013', 'Methylphenobarbital', '1932', '89', []),
#  ('8099', 'Phenobarbital', '1911', '110', []),
#  ('8135', 'Amobarbital', '1924', '97', []),
#  ('8136', 'Aprobarbital', '1920', '101', []),
#  ('8137', 'Butethal', '1923', '98', []),
#  ('8138', 'Heptabarbital', '1948', '73', []),
#  ('8139', 'Hexobarbital', '1932', '89', []),
#  ('8161', 'Barbital', '1903', '118', []),
#  ('7775', 'Levallorphan', '1951', '70', []),
#  ('7784', 'Naltrexone', '1984', '37', []),
#  ('7785', 'Alfentanil', '1983', '38', []),
#  ('7788', 'Nalbuphine', '1979', '42', []),
#  ('7790', 'Anileridine', '1958', '63', []),
#  ('7791', 'Buprenorphine', '1978', '43', []),
#  ('7803', 'Naloxone', '1969', '52', []),
#  ('7804', 'Oxymorphone', '1959', '62', []),
#  ('7805', 'Dezocine', '1986', '35', []),
#  ('7812', 'Methadyl Acetate', '1993', '28', []),
#  ('7823', 'Alvimopan', '2008', '13', []),
#  ('7826', 'Methylnaltrexone', '2008', '13', []),
#  ('7852', 'Glycine', '1978', '43', []),
#  ('7859', 'Tramadol', '1977', '44', []),
#  ('7892', 'Morphine', '1817', '204', []),
#  ('7903', 'Codeine', '1832', '189', []),
#  ('7905', 'Hydromorphone', '1926', '95', []),
#  ('7906', 'Methadone', '1947', '74', []),
#  ('7930', 'Pethidine', '1943', '78', []),
#  ('7941', 'Oxycodone', '1917', '104', []),
#  ('7944', 'Dextromethorphan', '1953', '68', []),
#  ('7965', 'Butorphanol', '1978', '43', []),
#  ('7970', 'Dextropropoxyphene', '1957', '64', []),
#  ('7971', 'Pentazocine', '1964', '57', []),
#  ('7975', 'Aprepitant', '2003', '18', []),
#  ('7982', 'Sufentanil', '1979', '42', []),
#  ('8003', 'Fentanyl', '1963', '58', []),
#  ('8007', 'Menthol', '1774', '247', []),
#  ('8009', 'Loperamide', '1975', '46', []),
#  ('8015', 'Levorphanol', '1951', '70', []),
#  ('8027', 'Remifentanil', '1996', '25', []),
#  ('8038', 'Felbamate', '1993', '28', []),
#  ('8041', 'Hydrocodone', '1924', '97', []),
#  ('8064', 'Memantine', '1983', '38', []),
#  ('8070', 'Diphenoxylate', '1960', '61', []),
#  ('8073', 'Pentolinium', '1952', '69', []),
#  ('8083', 'Trimethaphan', '1953', '68', []),
#  ('8093', 'Halothane', '1956', '65', []),
#  ('8115', 'Ketamine', '1963', '58', []),
#  ('8116', 'Levomethadyl Acetate', '1993', '28', []),
#  ('8156', 'Heroin', '1898', '123', []),
#  ('8167', 'Dihydromorphine', '1913', '108', []),
#  ('8177', 'Phencyclidine', '1950', '71', []),
#  ('8183', 'Vapreotide', '2005', '16', []),
#  ('8204', 'Ketobemidone', '1952', '69', []),
#  ('8217', 'Ifenprodil', '1972', '49', []),
#  ('7760', 'Tadalafil', '2002', '19', []),
#  ('7762', 'Avanafil', '2012', '9', []),
#  ('7766', 'Caffeine', '1910', '111', []),
#  ('7768', 'Sildenafil', '1998', '23', []),
#  ('7769', 'Milrinone', '1987', '34', []),
#  ('7770', 'Anagrelide', '1997', '24', []),
#  ('7771', 'Theophylline', '1902', '119', []),
#  ('7772', 'Mefloquine', '1989', '32', []),
#  ('7778', 'Pentostatin', '1991', '30', []),
#  ('7779', 'Chloroquine', '1947', '74', []),
#  ('7781', 'Dyphylline', '1948', '73', []),
#  ('7786', 'Pentoxifylline', '1972', '49', []),
#  ('7789', 'Vardenafil', '2003', '18', []),
#  ('7792', 'Levosimendan', '2000', '21', []),
#  ('7794', 'Dipyridamole', '1961', '60', []),
#  ('7799', 'Primaquine', '1952', '69', []),
#  ('7800', 'Papaverine', '1914', '107', []),
#  ('7802', 'Cilostazol', '1999', '22', []),
#  ('7806', 'Aminophylline', '1908', '113', []),
#  ('7809', 'Oxtriphylline', '1951', '70', []),
#  ('7811', 'Amrinone', '1982', '39', []),
#  ('7815', 'Roflumilast', '2010', '11', []),
#  ('7818', 'Enoximone', '1989', '32', []),
#  ('7819', 'Ibudilast', '1989', '32', []),
#  ('7822', 'Udenafil', '2005', '16', []),
#  ('7827', 'Tofisopam', '1975', '46', []),
#  ('7933', 'Quinine', '1827', '194', []),
#  ('7889', 'Acarbose', '1995', '26', []),
#  ('7940', 'Miglitol', '1996', '25', []),
#  ('8182', 'Voglibose', '1994', '27', []),
#  ('7849', 'Cetuximab', '2003', '18', []),
#  ('7858', 'Indecainide', '1989', '32', []),
#  ('7861', 'Fluconazole', '1988', '33', []),
#  ('7862', 'Dofetilide', '1999', '22', []),
#  ('7877', 'Oxiconazole', '1983', '38', []),
#  ('7879', 'Ranolazine', '2006', '15', []),
#  ('7881', 'Terconazole', '1987', '34', []),
#  ('7882', 'Phenytoin', '1938', '83', []),
#  ('7883', 'Clotrimazole', '1973', '48', []),
#  ('7888', 'Lidocaine', '1948', '73', []),
#  ('7893', 'Ropivacaine', '1996', '25', []),
#  ('7894', 'Bupivacaine', '1965', '56', []),
#  ('7896', 'Ibutilide', '1995', '26', []),
#  ('7902', 'Gefitinib', '2002', '19', []),
#  ('7914', 'Mexiletine', '1976', '45', []),
#  ('7935', 'Hexylcaine', '1952', '69', []),
#  ('7947', 'Cinchocaine', '1944', '77', []),
#  ('7949', 'Erlotinib', '2004', '17', []),
#  ('7950', 'Mephenytoin', '1945', '76', []),
#  ('7951', 'Lamotrigine', '1990', '31', []),
#  ('7953', 'Carbamazepine', '1963', '58', []),
#  ('7957', 'Voriconazole', '2002', '19', []),
#  ('7969', 'Dyclonine', '1956', '65', []),
#  ('7976', 'Moricizine', '1990', '31', []),
#  ('7988', 'Riluzole', '1995', '26', []),
#  ('7990', 'Prilocaine', '1963', '58', []),
#  ('7993', 'Ethotoin', '1957', '64', []),
#  ('7996', 'Oxcarbazepine', '1990', '31', []),
#  ('8001', 'Proparacaine', '1953', '68', []),
#  ('8005', 'Propofol', '1989', '32', []),
#  ('8019', 'Benzonatate', '1958', '63', []),
#  ('8025', 'Oxybuprocaine', '1953', '68', []),
#  ('8031', 'Quinidine', '1918', '103', []),
#  ('8043', 'Mepivacaine', '1959', '62', []),
#  ('8052', 'Levobupivacaine', '1999', '22', []),
#  ('8053', 'Cromoglicic acid', '1968', '53', []),
#  ('8054', 'Tioconazole', '1981', '40', []),
#  ('8059', 'Ketoconazole', '1981', '40', []),
#  ('8062', 'Procainamide', '1955', '66', []),
#  ('8066', 'Tocainide', '1981', '40', []),
#  ('8071', 'Benzocaine', '1902', '119', []),
#  ('8081', 'Miconazole', '1971', '50', []),
#  ('8086', 'Phenacemide', '1949', '72', []),
#  ('8087', 'Econazole', '1974', '47', []),
#  ('8089', 'Sertaconazole', '2003', '18', []),
#  ('8096', 'Itraconazole', '1988', '33', []),
#  ('8101', 'Propafenone', '1977', '44', []),
#  ('8107', 'Flecainide', '1982', '39', []),
#  ('8114', 'Halofantrine', '1984', '37', []),
#  ('8117', 'Encainide', '1987', '34', []),
#  ('8125', 'Lapatinib', '2007', '14', []),
#  ('8126', 'Posaconazole', '2005', '16', []),
#  ('8131', 'Fosphenytoin', '1996', '25', []),
#  ('8150', 'Ajmaline', '1958', '63', []),
#  ('8151', 'Aprindine', '1976', '45', []),
#  ('8153', 'Phenazopyridine', '1960', '61', []),
#  ('8178', 'Bifonazole', '1983', '38', []),
#  ('8185', 'Permethrin', '1986', '35', []),
#  ('8214', 'Afatinib', '2013', '8', []),
#  ('8216', 'LULICONAZOLE', '2013', '8', []),
#  ('8467', 'Vandetanib', '2011', '10', []),
#  ('7780', 'Adenosine', '1989', '32', []),
#  ('7821', 'Regadenoson', '2008', '13', []),
#  ('7825', 'Drotaverine', '1965', '56', []),
#  ('7865', 'Torasemide', '1993', '28', []),
#  ('7873', 'Pregabalin', '2004', '17', []),
#  ('7874', 'Methyclothiazide', '1960', '61', []),
#  ('7885', 'Isradipine', '1989', '32', []),
#  ('7887', 'Topiramate', '1996', '25', []),
#  ('7897', 'Chlorthalidone', '1960', '61', []),
#  ('7898', 'Ethoxzolamide', '1957', '64', []),
#  ('7907', 'Diltiazem', '1974', '47', []),
#  ('7909', 'Trimethadione', '1946', '75', []),
#  ('7915', 'Amlodipine', '1990', '31', []),
#  ('7917', 'Nimodipine', '1985', '36', []),
#  ('7919', 'Nisoldipine', '1990', '31', []),
#  ('7925', 'Methocarbamol', '1957', '64', []),
#  ('7928', 'Bendroflumethiazide', '1959', '62', []),
#  ('7943', 'Acetyldigitoxin', '1954', '67', []),
#  ('7946', 'Metolazone', '1973', '48', []),
#  ('7948', 'Lercanidipine', '1997', '24', []),
#  ('7952', 'Benzthiazide', '1960', '61', []),
#  ('7960', 'Ethosuximide', '1960', '61', []),
#  ('7963', 'Cyclothiazide', '1963', '58', []),
#  ('7972', 'Verapamil', '1963', '58', []),
#  ('7978', 'Furosemide', '1964', '57', []),
#  ('7981', 'Methazolamide', '1959', '62', []),
#  ('7987', 'Naftifine', '1988', '33', []),
#  ('7995', 'Hydroflumethiazide', '1959', '62', []),
#  ('8002', 'Indapamide', '1977', '44', []),
#  ('8006', 'Acetazolamide', '1953', '68', []),
#  ('8016', 'Terbinafine', '1990', '31', []),
#  ('8020', 'Dorzolamide', '1994', '27', []),
#  ('8022', 'Chlorothiazide', '1957', '64', []),
#  ('8023', 'Bumetanide', '1972', '49', []),
#  ('8028', 'Ethacrynic acid', '1966', '55', []),
#  ('8032', 'Zonisamide', '1989', '32', []),
#  ('8048', 'Gabapentin', '1993', '28', []),
#  ('8050', 'Hydrochlorothiazide', '1959', '62', []),
#  ('8057', 'Trichlormethiazide', '1960', '61', []),
#  ('8058', 'Felodipine', '1988', '33', []),
#  ('8061', 'Ethinamate', '1955', '66', []),
#  ('8065', 'Nitrendipine', '1985', '36', []),
#  ('8074', 'Butenafine', '1996', '25', []),
#  ('8075', 'Ouabain', '1908', '113', []),
#  ('8082', 'Nifedipine', '1975', '46', []),
#  ('8085', 'Diazoxide', '1970', '51', []),
#  ('8088', 'Diclofenamide', '1958', '63', []),
#  ('8092', 'Bretylium', '1973', '48', []),
#  ('8106', 'Brinzolamide', '2000', '21', []),
#  ('8111', 'Levetiracetam', '1999', '22', []),
#  ('8121', 'Bepridil', '1981', '40', []),
#  ('8132', 'Polythiazide', '1961', '60', []),
#  ('8133', 'Quinethazone', '1963', '58', []),
#  ('8146', 'Mibefradil', '1997', '24', []),
#  ('8147', 'Digitoxin', '1949', '72', []),
#  ('8176', 'Piretanide', '1980', '41', []),
#  ('8180', 'Cyclandelate', '1958', '63', []),
#  ('8188', 'Methsuximide', '1957', '64', []),
#  ('8205', 'Mafenide', '1948', '73', []),
#  ('8271', 'Cinnarizine', '1961', '60', []),
#  ('7763', 'Succinic acid', '2008', '13', []),
#  ('7776', 'Chlormerodrin', '1952', '69', []),
#  ('7850', 'Pyridoxal Phosphate', '1939', '82', []),
#  ('7851', 'Pyruvic acid', '1990', '31', []),
#  ('7853', 'L-Alanine', '1971', '50', []),
#  ('7855', 'Baclofen', '1971', '50', []),
#  ('7872', 'Enflurane', '1972', '49', []),
#  ('7900', 'Valproic Acid', '1967', '54', []),
#  ('7911', 'Meprobamate', '1955', '66', []),
#  ('7920', 'Eszopiclone', '2004', '17', []),
#  ('7926', 'Zolpidem', '1988', '33', []),
#  ('7966', 'Clorazepate', '1967', '54', []),
#  ('7992', 'Isoflurane', '1979', '42', []),
#  ('8010', 'Progabide', '1985', '36', []),
#  ('8026', 'Ethanol', '1763', '258', []),
#  ('8060', 'Methoxyflurane', '1962', '59', []),
#  ('8069', 'Vigabatrin', '1989', '32', []),
#  ('8080', 'Methyprylon', '1955', '66', []),
#  ('8090', 'Thiamylal', '1951', '70', []),
#  ('8100', 'Chlormezanone', '1958', '63', []),
#  ('8103', 'Desflurane', '1992', '29', []),
#  ('8108', 'Zopiclone', '1987', '34', []),
#  ('8119', 'Sevoflurane', '1990', '31', []),
#  ('8152', 'Glutethimide', '1954', '67', []),
#  ('8166', 'Flunitrazepam', '1974', '47', []),
#  ('8172', 'Ketazolam', '1980', '41', []),
#  ('8210', 'Perampanel', '2012', '9', []),
#  ('8211', 'Arbaclofen', '2011', '10', []),
#  ('8438', 'Phenformin', '1959', '62', []),
#  ('8455', 'Glisoxepide', '1974', '47', []),
#  ('7854', 'Fluvoxamine', '1983', '38', []),
#  ('7856', 'Amphetamine', '1932', '89', []),
#  ('7857', 'Phentermine', '1959', '62', []),
#  ('7863', 'Reserpine', '1953', '68', []),
#  ('7864', 'Midodrine', '1977', '44', []),
#  ('7866', 'Citalopram', '1989', '32', []),
#  ('7867', 'Eletriptan', '2001', '20', []),
#  ('7869', 'Isoetarine', '1941', '80', []),
#  ('7871', 'Guanadrel', '1983', '38', []),
#  ('7875', 'Reboxetine', '1997', '24', []),
#  ('7880', 'Cabergoline', '1993', '28', []),
#  ('7884', 'Ropinirole', '1996', '25', []),
#  ('7890', 'Venlafaxine', '1993', '28', []),
#  ('7891', 'Etomidate', '1972', '49', []),
#  ('7901', 'Zolmitriptan', '1997', '24', []),
#  ('7904', 'Dihydroergotamine', '1946', '75', []),
#  ('7908', 'Protriptyline', '1966', '55', []),
#  ('7910', 'Norepinephrine', '1950', '71', []),
#  ('7916', 'Alseroxylon', '1952', '69', []),
#  ('7918', 'Phenylpropanolamine', '1938', '83', []),
#  ('7921', 'Pramipexole', '1997', '24', []),
#  ('7924', 'Methylphenidate', '1955', '66', []),
#  ('7929', 'Dipivefrin', '1978', '43', []),
#  ('7934', 'Fluoxetine', '1987', '34', []),
#  ('7937', 'Duloxetine', '2004', '17', []),
#  ('7938', 'Brimonidine', '1996', '25', []),
#  ('7954', 'Fenfluramine', '1963', '58', []),
#  ('7955', 'Clonidine', '1966', '55', []),
#  ('7956', 'Mazindol', '1975', '46', []),
#  ('7958', 'Lisuride', '1968', '53', []),
#  ('7962', 'Cisapride', '1990', '31', []),
#  ('7964', 'Metaraminol', '1954', '67', []),
#  ('7967', 'Guanabenz', '1982', '39', []),
#  ('7968', 'Dexmedetomidine', '1999', '22', []),
#  ('7973', 'Epinephrine', '1901', '120', []),
#  ('7974', 'Sumatriptan', '1990', '31', []),
#  ('7979', 'Ergotamine', '1921', '100', []),
#  ('7980', 'Tizanidine', '1996', '25', []),
#  ('7983', 'Apomorphine', '1869', '152', []),
#  ('7984', 'Procaine', '1905', '116', []),
#  ('7985', 'Methoxamine', '1949', '72', []),
#  ('7989', 'Modafinil', '1986', '35', []),
#  ('7991', 'Tranylcypromine', '1960', '61', []),
#  ('7997', 'Phenelzine', '1959', '62', []),
#  ('7999', 'Fenoldopam', '1994', '27', []),
#  ('8000', 'Minaprine', '1979', '42', []),
#  ('8004', 'Orciprenaline', '1961', '60', []),
#  ('8008', 'Phenmetrazine', '1954', '67', []),
#  ('8012', 'Dobutamine', '1977', '44', []),
#  ('8014', 'Pseudoephedrine', '1958', '63', []),
#  ('8017', 'Benzphetamine', '1960', '61', []),
#  ('8018', 'Ritodrine', '1975', '46', []),
#  ('8021', 'Terbutaline', '1970', '51', []),
#  ('8030', 'Cocaine', '1884', '137', []),
#  ('8033', 'Amantadine', '1966', '55', []),
#  ('8034', 'Almotriptan', '2000', '21', []),
#  ('8035', 'Oxymetazoline', '1961', '60', []),
#  ('8036', 'Diethylpropion', '1959', '62', []),
#  ('8037', 'Salmeterol', '1990', '31', []),
#  ('8039', 'Naratriptan', '1997', '24', []),
#  ('8040', 'Rizatriptan', '1998', '23', []),
#  ('8042', 'Pindolol', '1978', '43', []),
#  ('8044', 'Apraclonidine', '1988', '33', []),
#  ('8046', 'Formoterol', '1986', '35', []),
#  ('8047', 'Dopamine', '1974', '47', []),
#  ('8049', 'Frovatriptan', '2000', '21', []),
#  ('8051', 'Salbutamol', '1969', '52', []),
#  ('8056', 'Guanfacine', '1980', '41', []),
#  ('8063', 'Selegiline', '1982', '39', []),
#  ('8067', 'Isoprenaline', '1949', '72', []),
#  ('8072', 'Deserpidine', '1957', '64', []),
#  ('8077', 'Arbutamine', '1997', '24', []),
#  ('8078', 'Sertraline', '1991', '30', []),
#  ('8079', 'Sibutramine', '1995', '26', []),
#  ('8091', 'Bupropion', '1982', '39', []),
#  ('8094', 'Chloroprocaine', '1952', '69', []),
#  ('8097', 'Moclobemide', '1989', '32', []),
#  ('8102', 'Pergolide', '1982', '39', []),
#  ('8104', 'Dexfenfluramine', '1985', '36', []),
#  ('8105', 'Acebutolol', '1973', '48', []),
#  ('8110', 'Bromocriptine', '1975', '46', []),
#  ('8118', 'L-DOPA', '1967', '54', []),
#  ('8120', 'Clomipramine', '1968', '53', []),
#  ('8122', 'Isocarboxazid', '1959', '62', []),
#  ('8123', 'Ergonovine', '1939', '82', []),
#  ('8124', 'Lisdexamfetamine', '2007', '14', []),
#  ('8127', 'Arformoterol', '2006', '15', []),
#  ('8128', 'Hydralazine', '1952', '69', []),
#  ('8129', 'Fenoterol', '1971', '50', []),
#  ('8130', 'Pirbuterol', '1982', '39', []),
#  ('8140', 'Ephedra', '1886', '135', []),
#  ('8141', 'Ephedrine', '1926', '95', []),
#  ('8142', 'Mephentermine', '1947', '74', []),
#  ('8143', 'Procaterol', '1980', '41', []),
#  ('8144', 'Rasagiline', '2005', '16', []),
#  ('8145', 'Ginkgo biloba', '1973', '48', []),
#  ('8148', 'Clenbuterol', '1977', '44', []),
#  ('8149', 'Bambuterol', '1990', '31', []),
#  ('8158', 'Fencamfamine', '1962', '59', []),
#  ('8170', 'Methamphetamine', '1943', '78', []),
#  ('8171', 'Phendimetrazine', '1961', '60', []),
#  ('8174', 'Pargyline', '1963', '58', []),
#  ('8179', 'Zimelidine', '1981', '40', []),
#  ('8184', 'Milnacipran', '2009', '12', []),
#  ('8186', 'Lofexidine', '1981', '40', []),
#  ('8187', 'Indacaterol', '2009', '12', []),
#  ('8189', 'Rotigotine', '2006', '15', []),
#  ('8190', 'Tapentadol', '2008', '13', []),
#  ('8191', 'Droxidopa', '1989', '32', []),
#  ('8194', 'Vilazodone', '2011', '10', []),
#  ('8195', 'Xylometazoline', '1959', '62', []),
#  ('8196', 'Desvenlafaxine', '2008', '13', []),
#  ('8197', 'Dexmethylphenidate', '2001', '20', []),
#  ('8198', 'Isometheptene', '1948', '73', []),
#  ('8199', 'Levonordefrin', '1960', '61', []),
#  ('8200', 'Naphazoline', '1942', '79', []),
#  ('8202', 'Propylhexedrine', '1949', '72', []),
#  ('8213', 'Mirabegron', '2012', '9', []),
#  ('8215', 'Levomilnacipran', '2013', '8', []),
#  ('8218', 'Captodiame', '1958', '63', []),
#  ('8289', 'Trimipramine', '1964', '57', []),
#  ('8336', 'Chlorphenamine', '1949', '72', []),
#  ('8342', 'Nefazodone', '1994', '27', []),
#  ('8344', 'Escitalopram', '2002', '19', []),
#  ('7860', 'Betaxolol', '1983', '38', []),
#  ('7912', 'Timolol', '1974', '47', []),
#  ('7939', 'Sotalol', '1974', '47', []),
#  ('7945', 'Carteolol', '1980', '41', []),
#  ('8084', 'Amiodarone', '1962', '59', []),
#  ('8113', 'Metipranolol', '1989', '32', []),
#  ('8219', 'Esmolol', '1986', '35', []),
#  ('8223', 'Metoprolol', '1975', '46', []),
#  ('8230', 'Atenolol', '1975', '46', []),
#  ('8272', 'Propranolol', '1964', '57', []),
#  ('8275', 'Labetalol', '1977', '44', []),
#  ('8276', 'Bisoprolol', '1986', '35', []),
#  ('8310', 'Alprenolol', '1967', '54', []),
#  ('8347', 'Nadolol', '1978', '43', []),
#  ('8348', 'Levobunolol', '1985', '36', []),
#  ('8359', 'Practolol', '1970', '51', []),
#  ('8362', 'Penbutolol', '1980', '41', []),
#  ('8367', 'Oxprenolol', '1970', '51', []),
#  ('8386', 'Nebivolol', '1997', '24', []),
#  ('8405', 'Bupranolol', '1969', '52', []),
#  ('7886', 'Betazole', '1953', '68', []),
#  ('7913', 'Palonosetron', '2003', '18', []),
#  ('7959', 'Doxazosin', '1988', '33', []),
#  ('7986', 'Atracurium', '1983', '38', []),
#  ('7994', 'Dolasetron', '1997', '24', []),
#  ('8024', 'Granisetron', '1991', '30', []),
#  ('8029', 'Ondansetron', '1990', '31', []),
#  ('8045', 'Alosetron', '2000', '21', []),
#  ('8095', 'Terazosin', '1985', '36', []),
#  ('8169', 'Dextroamphetamine', '1976', '45', []),
#  ('8181', 'Dronedarone', '2009', '12', []),
#  ('8192', 'Agomelatine', '2009', '12', []),
#  ('8193', 'Dalfampridine', '2010', '11', []),
#  ('8207', 'Cinitapride', '1990', '31', []),
#  ('8221', 'Ziprasidone', '2001', '20', []),
#  ('8222', 'Methysergide', '1959', '62', []),
#  ('8224', 'Disopyramide', '1977', '44', []),
#  ('8226', 'Dapiprazole', '1990', '31', []),
#  ('8227', 'Amitriptyline', '1961', '60', []),
#  ('8228', 'Ipratropium bromide', '1974', '47', []),
#  ('8229', 'Olanzapine', '1996', '25', []),
#  ('8231', 'Metixene', '1960', '61', []),
#  ('8234', 'Alfuzosin', '1988', '33', []),
#  ('8235', 'Methylergometrine', '1946', '75', []),
#  ('8237', 'Clozapine', '1972', '49', []),
#  ('8240', 'Thiethylperazine', '1961', '60', []),
#  ('8241', 'Trihexyphenidyl', '1949', '72', []),
#  ('8242', 'Oxyphencyclimine', '1959', '62', []),
#  ('8243', 'Procyclidine', '1955', '66', []),
#  ('8244', 'Sulpiride', '1968', '53', []),
#  ('8245', 'Ethopropazine', '1952', '69', []),
#  ('8247', 'Loxapine', '1975', '46', []),
#  ('8248', 'Remoxipride', '1989', '32', []),
#  ('8249', 'Promazine', '1956', '65', []),
#  ('8250', 'Hyoscyamine', '1960', '61', []),
#  ('8252', 'Prochlorperazine', '1956', '65', []),
#  ('8253', 'Cyproheptadine', '1961', '60', []),
#  ('8254', 'Droperidol', '1963', '58', []),
#  ('8256', 'Prazosin', '1974', '47', []),
#  ('8257', 'Imipramine', '1959', '62', []),
#  ('8258', 'Methylscopolamine bromide', '1947', '74', []),
#  ('8259', 'Chlorpromazine', '1952', '69', []),
#  ('8260', 'Gallamine Triethiodide', '1951', '70', []),
#  ('8261', 'Buspirone', '1986', '35', []),
#  ('8262', 'Darifenacin', '2004', '17', []),
#  ('8264', 'Haloperidol', '1959', '62', []),
#  ('8265', 'Tridihexethyl', '1954', '67', []),
#  ('8266', 'Triflupromazine', '1957', '64', []),
#  ('8267', 'Anisotropine Methylbromide', '1962', '59', []),
#  ('8268', 'Nortriptyline', '1963', '58', []),
#  ('8269', 'Amoxapine', '1980', '41', []),
#  ('8273', 'Atropine', '1877', '144', []),
#  ('8277', 'Nicardipine', '1981', '40', []),
#  ('8278', 'Fluphenazine', '1959', '62', []),
#  ('8281', 'Histamine Phosphate', '1939', '82', []),
#  ('8282', 'Thioridazine', '1959', '62', []),
#  ('8283', 'Phentolamine', '1952', '69', []),
#  ('8284', 'Nicergoline', '1972', '49', []),
#  ('8285', 'Tamsulosin', '1993', '28', []),
#  ('8286', 'Paroxetine', '1991', '30', []),
#  ('8288', 'Homatropine Methylbromide', '1880', '141', []),
#  ('8290', 'Rocuronium', '1994', '27', []),
#  ('8291', 'Risperidone', '1993', '28', []),
#  ('8293', 'Scopolamine', '1902', '119', []),
#  ('8296', 'Benzquinamide', '1974', '47', []),
#  ('8298', 'Clidinium', '1961', '60', []),
#  ('8299', 'Propiomazine', '1960', '61', []),
#  ('8300', 'Propantheline', '1953', '68', []),
#  ('8301', 'Cryptenamine', '1954', '67', []),
#  ('8303', 'Tolazoline', '1948', '73', []),
#  ('8304', 'Dicyclomine', '1950', '71', []),
#  ('8305', 'Tropicamide', '1951', '70', []),
#  ('8306', 'Trifluoperazine', '1958', '63', []),
#  ('8307', 'Brompheniramine', '1955', '66', []),
#  ('8308', 'Perphenazine', '1957', '64', []),
#  ('8311', 'Flupentixol', '1965', '56', []),
#  ('8314', 'Cyclobenzaprine', '1977', '44', []),
#  ('8315', 'Phenoxybenzamine', '1953', '68', []),
#  ('8317', 'Mesoridazine', '1970', '51', []),
#  ('8318', 'Maprotiline', '1972', '49', []),
#  ('8323', 'Glycopyrrolate', '1961', '60', []),
#  ('8324', 'Tolterodine', '1998', '23', []),
#  ('8325', 'Carphenazine', '1962', '59', []),
#  ('8326', 'Ergoloid mesylate', '1953', '68', []),
#  ('8327', 'Oxybutynin', '1975', '46', []),
#  ('8328', 'Acetophenazine', '1961', '60', []),
#  ('8329', 'Promethazine', '1949', '72', []),
#  ('8332', 'Tegaserod', '2002', '19', []),
#  ('8334', 'Pimozide', '1971', '50', []),
#  ('8337', 'Doxacurium chloride', '1992', '29', []),
#  ('8338', 'Carvedilol', '1991', '30', []),
#  ('8339', 'Doxepin', '1969', '52', []),
#  ('8341', 'Flavoxate', '1970', '51', []),
#  ('8343', 'Desipramine', '1963', '58', []),
#  ('8346', 'Domperidone', '1979', '42', []),
#  ('8349', 'Quetiapine', '1996', '25', []),
#  ('8350', 'Mivacurium', '1994', '27', []),
#  ('8351', 'Diphenidol', '1967', '54', []),
#  ('8352', 'Metoclopramide', '1964', '57', []),
#  ('8354', 'Aripiprazole', '2002', '19', []),
#  ('8355', 'Chlorprothixene', '1960', '61', []),
#  ('8357', 'Paliperidone', '2006', '15', []),
#  ('8360', 'Pancuronium', '1972', '49', []),
#  ('8361', 'Pipecuronium', '1990', '31', []),
#  ('8364', 'Methotrimeprazine', '1958', '63', []),
#  ('8365', 'Tiotropium', '2002', '19', []),
#  ('8366', 'Alizapride', '1981', '40', []),
#  ('8368', 'Solifenacin', '2004', '17', []),
#  ('8369', 'Propericiazine', '1969', '52', []),
#  ('8372', 'Alverine', '1996', '25', []),
#  ('8373', 'Molindone', '1974', '47', []),
#  ('8376', 'Pipotiazine', '1980', '41', []),
#  ('8377', 'Thioproperazine', '1960', '61', []),
#  ('8378', 'Thiothixene', '1967', '54', []),
#  ('8379', 'Zuclopenthixol', '1995', '26', []),
#  ('8380', 'Isopropamide', '1957', '64', []),
#  ('8383', 'Fluspirilene', '1972', '49', []),
#  ('8384', 'Mepenzolate', '1956', '65', []),
#  ('8385', 'Tetrabenazine', '1960', '61', []),
#  ('8389', 'Iloperidone', '2009', '12', []),
#  ('8390', 'Sertindole', '1996', '25', []),
#  ('8391', 'Mianserin', '1975', '46', []),
#  ('8392', 'Silodosin', '2006', '15', []),
#  ('8393', 'Asenapine', '2009', '12', []),
#  ('8394', 'Amisulpride', '1986', '35', []),
#  ('8396', 'Betahistine', '1968', '53', []),
#  ('8397', 'Fesoterodine', '2007', '14', []),
#  ('8406', 'Lurasidone', '2010', '11', []),
#  ('8407', 'Aclidinium', '2012', '9', []),
#  ('8411', 'Bromopride', '1977', '44', []),
#  ('8581', 'Cisatracurium Besylate', '1995', '26', []),
#  ('8582', 'Mecamylamine', '1956', '65', []),
#  ('8583', 'Vecuronium', '1984', '37', []),
#  ('8584', 'Trospium', '1990', '31', []),
#  ('8586', 'Pirenzepine', '1984', '37', []),
#  ('8587', 'Diphemanil Methylsulfate', '1952', '69', []),
#  ('8588', 'Biperiden', '1959', '62', []),
#  ('8590', 'Cycrimine', '1953', '68', []),
#  ('8591', 'Cyclopentolate', '1953', '68', []),
#  ('7927', 'Lindane', '1951', '70', []),
#  ('7936', 'Methohexital', '1960', '61', []),
#  ('8112', 'Flumazenil', '1991', '30', []),
#  ('7835', 'Gadopentetate dimeglumine', '1987', '34', []),
#  ('7837', 'Dacarbazine', '1975', '46', []),
#  ('8098', 'Orphenadrine', '1957', '64', []),
#  ('8220', 'Benzatropine', '1954', '67', []),
#  ('8225', 'Clemastine', '1967', '54', []),
#  ('8232', 'Cetirizine', '1987', '34', []),
#  ('8233', 'Terfenadine', '1983', '38', []),
#  ('8236', 'Buclizine', '1957', '64', []),
#  ('8238', 'Doxylamine', '1948', '73', []),
#  ('8239', 'Mirtazapine', '1994', '27', []),
#  ('8246', 'Dexbrompheniramine', '1959', '62', []),
#  ('8251', 'Triprolidine', '1953', '68', []),
#  ('8255', 'Loratadine', '1988', '33', []),
#  ('8263', 'Cimetidine', '1977', '44', []),
#  ('8270', 'Hydroxyzine', '1956', '65', []),
#  ('8274', 'Nizatidine', '1987', '34', []),
#  ('8279', 'Astemizole', '1983', '38', []),
#  ('8280', 'Trazodone', '1972', '49', []),
#  ('8287', 'Azatadine', '1968', '53', []),
#  ('8292', 'Meclizine', '1953', '68', []),
#  ('8294', 'Carbinoxamine', '1953', '68', []),
#  ('8295', 'Epinastine', '2003', '18', []),
#  ('8297', 'Olopatadine', '1997', '24', []),
#  ('8302', 'Tripelennamine', '1946', '75', []),
#  ('8309', 'Ranitidine', '1981', '40', []),
#  ('8312', 'Methdilazine', '1960', '61', []),
#  ('8313', 'Ketotifen', '1978', '43', []),
#  ('8316', 'Famotidine', '1985', '36', []),
#  ('8319', 'Fexofenadine', '1996', '25', []),
#  ('8320', 'Desloratadine', '2001', '20', []),
#  ('8321', 'Azelastine', '1986', '35', []),
#  ('8322', 'Dimenhydrinate', '1949', '72', []),
#  ('8330', 'Mequitazine', '1976', '45', []),
#  ('8331', 'Diphenhydramine', '1946', '75', []),
#  ('8333', 'Emedastine', '1993', '28', []),
#  ('8335', 'Levocabastine', '1993', '28', []),
#  ('8340', 'Diphenylpyraline', '1951', '70', []),
#  ('8345', 'Cyclizine', '1953', '68', []),
#  ('8356', 'Alimemazine', '1958', '63', []),
#  ('8374', 'Phenindamine', '1947', '74', []),
#  ('8375', 'Pheniramine', '1948', '73', []),
#  ('8381', 'Clofedanol', '1958', '63', []),
#  ('8382', 'Flunarizine', '1977', '44', []),
#  ('8387', 'Bepotastine', '2000', '21', []),
#  ('8395', 'Mepyramine', '1948', '73', []),
#  ('8398', 'Alcaftadine', '2010', '11', []),
#  ('8399', 'Antazoline', '1948', '73', []),
#  ('8401', 'Dimetindene', '1960', '61', []),
#  ('8402', 'Isothipendyl', '1957', '64', []),
#  ('8404', 'Roxatidine acetate', '1986', '35', []),
#  ('8409', 'Chlorcyclizine', '1949', '72', []),
#  ('8410', 'Butriptyline', '1975', '46', []),
#  ('8421', 'Travoprost', '2001', '20', []),
#  ('8424', 'Carboprost Tromethamine', '1979', '42', []),
#  ('8433', 'Latanoprost', '1995', '26', []),
#  ('8436', 'Alprostadil', '1981', '40', []),
#  ('8437', 'Bimatoprost', '2001', '20', []),
#  ('8439', 'Dinoprostone', '1972', '49', []),
#  ('8440', 'Misoprostol', '1986', '35', []),
#  ('8449', 'Dinoprost Tromethamine', '1975', '46', []),
#  ('8479', 'Tafluprost', '2012', '9', []),
#  ('8596', 'Treprostinil', '2002', '19', []),
#  ('8620', 'Iloprost', '1992', '29', []),
#  ('8624', 'Epoprostenol', '1995', '26', []),
#  ('8412', 'Lepirudin', '1997', '24', []),
#  ('8413', 'Bivalirudin', '2000', '21', []),
#  ('8420', 'Argatroban', '2000', '21', []),
#  ('8459', 'Hirulog', '2000', '21', []),
#  ('8461', 'Suramin', '1920', '101', []),
#  ('8476', 'Dabigatran etexilate', '2008', '13', []),
#  ('7796', 'Amlexanox', '1996', '25', []),
#  ('7977', 'Pentosan Polysulfate', '1993', '28', []),
#  ('8423', 'Sorafenib', '2005', '16', []),
#  ('8430', 'Imatinib', '2001', '20', []),
#  ('8452', 'Dasatinib', '2006', '15', []),
#  ('8454', 'Sunitinib', '2006', '15', []),
#  ('8473', 'Bosutinib', '2012', '9', []),
#  ('8474', 'Axitinib', '2012', '9', []),
#  ('8482', 'Crizotinib', '2011', '10', []),
#  ('8483', 'Cabozantinib', '2012', '9', []),
#  ('8485', 'Vemurafenib', '2011', '10', []),
#  ('8487', 'Regorafenib', '2012', '9', []),
#  ('8488', 'Ponatinib', '2012', '9', []),
#  ('8489', 'Trametinib', '2013', '8', []),
#  ('8490', 'Dabrafenib', '2013', '8', []),
#  ('8576', 'Flavopiridol', '2007', '14', []),
#  ('7773', 'Progesterone', '1935', '86', []),
#  ('7777', 'Cefdinir', '1991', '30', []),
#  ('7782', 'Tamoxifen', '1973', '48', []),
#  ('7783', 'Eplerenone', '2002', '19', []),
#  ('7793', 'Fulvestrant', '2002', '19', []),
#  ('7820', 'Abiraterone', '2011', '10', []),
#  ('7847', 'Clomifene', '1966', '55', []),
#  ('7848', 'Ospemifene', '2013', '8', []),
#  ('7942', 'Flutamide', '1983', '38', []),
#  ('8076', 'Leflunomide', '1998', '23', []),
#  ('8417', 'Pravastatin', '1989', '32', []),
#  ('8418', 'Lovastatin', '1987', '34', []),
#  ('8419', 'Nevirapine', '1998', '23', []),
#  ('8422', 'Tenofovir', '2001', '20', []),
#  ('8425', 'Cerivastatin', '1997', '24', []),
#  ('8426', 'Zidovudine', '1987', '34', []),
#  ('8429', 'Rifabutin', '1992', '29', []),
#  ('8431', 'Efavirenz', '1998', '23', []),
#  ('8432', 'Simvastatin', '1988', '33', []),
#  ('8434', 'Delavirdine', '1997', '24', []),
#  ('8435', 'Lamivudine', '1995', '26', []),
#  ('8441', 'Zalcitabine', '1992', '29', []),
#  ('8442', 'Rifampicin', '1968', '53', []),
#  ('8443', 'Atorvastatin', '1996', '25', []),
#  ('8444', 'Fluvastatin', '1994', '27', []),
#  ('8445', 'Rosuvastatin', '2003', '18', []),
#  ('8447', 'Atovaquone', '1992', '29', []),
#  ('8450', 'Rifaximin', '2004', '17', []),
#  ('8453', 'Sitagliptin', '2006', '15', []),
#  ('8468', 'Alogliptin', '2013', '8', []),
#  ('8470', 'Saxagliptin', '2009', '12', []),
#  ('8480', 'Pitavastatin', '2003', '18', []),
#  ('8481', 'Rilpivirine', '2011', '10', []),
#  ('8484', 'Teriflunomide', '2012', '9', []),
#  ('8486', 'Linagliptin', '2011', '10', []),
#  ('8491', 'Diethylstilbestrol', '1941', '80', []),
#  ('8492', 'Chlorotrianisene', '1952', '69', []),
#  ('8493', 'Conjugated Estrogens', '1941', '80', []),
#  ('8494', 'Etonogestrel', '1998', '23', []),
#  ('8495', 'Desogestrel', '1981', '40', []),
#  ('8496', 'Levonorgestrel', '1966', '55', []),
#  ('8497', 'Dydrogesterone', '1961', '60', []),
#  ('8498', 'Spironolactone', '1959', '62', []),
#  ('8499', 'Raloxifene', '1998', '23', []),
#  ('8500', 'Fluticasone Propionate', '1990', '31', []),
#  ('8501', 'Medroxyprogesterone Acetate', '1958', '63', []),
#  ('8502', 'Oxandrolone', '1964', '57', []),
#  ('8503', 'Testosterone', '1937', '84', []),
#  ('8504', 'Estrone', '1951', '70', []),
#  ('8505', 'Nilutamide', '1987', '34', []),
#  ('8506', 'Norethindrone', '1957', '64', []),
#  ('8507', 'Estradiol', '1936', '85', []),
#  ('8508', 'Ethynodiol', '1965', '56', []),
#  ('8509', 'Mifepristone', '1988', '33', []),
#  ('8510', 'Drostanolone', '1961', '60', []),
#  ('8511', 'Dienestrol', '1951', '70', []),
#  ('8512', 'Norgestimate', '1986', '35', []),
#  ('8513', 'Ethinylestradiol', '1938', '83', []),
#  ('8514', 'Nandrolone phenpropionate', '1959', '62', []),
#  ('8517', 'Bicalutamide', '1995', '26', []),
#  ('8518', 'Fluoxymesterone', '1956', '65', []),
#  ('8519', 'Estramustine', '1973', '48', []),
#  ('8520', 'Budesonide', '1981', '40', []),
#  ('8521', 'Mestranol', '1957', '64', []),
#  ('8522', 'Drospirenone', '2000', '21', []),
#  ('8523', 'Danazol', '1972', '49', []),
#  ('8524', 'Testosterone Propionate', '1937', '84', []),
#  ('8525', 'Allylestrenol', '1961', '60', []),
#  ('8530', 'Estropipate', '1968', '53', []),
#  ('8531', 'Quinestrol', '1968', '53', []),
#  ('8532', 'Cyproterone acetate', '1973', '48', []),
#  ('8533', 'Methyltestosterone', '1936', '85', []),
#  ('8534', 'Norelgestromin', '2001', '20', []),
#  ('8535', 'Nandrolone decanoate', '1962', '59', []),
#  ('8536', 'Enzalutamide', '2012', '9', []),
#  ('8537', 'Flunisolide', '1978', '43', []),
#  ('8538', 'Diflorasone', '1978', '43', []),
#  ('8539', 'Alclometasone', '1985', '36', []),
#  ('8540', 'Medrysone', '1970', '51', []),
#  ('8541', 'Amcinonide', '1978', '43', []),
#  ('8542', 'Fluorometholone', '1959', '62', []),
#  ('8543', 'Megestrol acetate', '1963', '58', []),
#  ('8544', 'Beclomethasone', '1972', '49', []),
#  ('8545', 'Betamethasone', '1961', '60', []),
#  ('8546', 'Desoximetasone', '1968', '53', []),
#  ('8547', 'Azelaic Acid', '1996', '25', []),
#  ('8548', 'Fluocinolone Acetonide', '1961', '60', []),
#  ('8549', 'Halobetasol Propionate', '1991', '30', []),
#  ('8551', 'Triamcinolone', '1958', '63', []),
#  ('8552', 'Prednisone', '1954', '67', []),
#  ('8553', 'Flumethasone (pivalate)', '1964', '57', []),
#  ('8554', 'Fludrocortisone', '1954', '67', []),
#  ('8555', 'Hydrocortisone', '1941', '80', []),
#  ('8556', 'Mometasone', '1987', '34', []),
#  ('8557', 'Hydrocortamate', '1956', '65', []),
#  ('8558', 'Clocortolone', '1977', '44', []),
#  ('8559', 'Flurandrenolide', '1962', '59', []),
#  ('8560', 'Prednisolone', '1955', '66', []),
#  ('8561', 'Loteprednol', '1998', '23', []),
#  ('8563', 'Methylprednisolone', '1955', '66', []),
#  ('8564', 'Clobetasol propionate', '1973', '48', []),
#  ('8565', 'Fluocinonide', '1970', '51', []),
#  ('8566', 'Dutasteride', '2001', '20', []),
#  ('8567', 'Prednicarbate', '1991', '30', []),
#  ('8569', 'Finasteride', '1992', '29', []),
#  ('8570', 'Dexamethasone', '1958', '63', []),
#  ('8571', 'Desonide', '1972', '49', []),
#  ('8572', 'Cortisone acetate', '1950', '71', []),
#  ('8573', 'Paramethasone', '1961', '60', []),
#  ('8574', 'Ciclesonide', '2005', '16', []),
#  ('8577', 'Difluprednate', '1978', '43', []),
#  ('8579', 'Fluticasone furoate', '2007', '14', []),
#  ('8606', 'Stavudine', '1994', '27', []),
#  ('8613', 'Emtricitabine', '2003', '18', []),
#  ('8615', 'Didanosine', '1991', '30', []),
#  ('8618', 'Abacavir', '1998', '23', []),
#  ('8427', 'Acetohydroxamic Acid', '1983', '38', []),
#  ('8428', 'Fondaparinux sodium', '2001', '20', []),
#  ('8446', 'Heparin', '1939', '82', []),
#  ('8451', 'Enoxaparin', '1993', '28', []),
#  ('8469', 'Rivaroxaban', '2008', '13', []),
#  ('8472', 'Apixaban', '2012', '9', []),
#  ('8477', 'Dalteparin', '1994', '27', []),
#  ('8478', 'Nadroparin', '1998', '23', []),
#  ('8578', 'Plerixafor', '2008', '13', []),
#  ('8594', 'Ramipril', '1989', '32', []),
#  ('8599', 'Fosinopril', '1990', '31', []),
#  ('8600', 'Trandolapril', '1993', '28', []),
#  ('8601', 'Benazepril', '1990', '31', []),
#  ('8602', 'Enalapril', '1984', '37', []),
#  ('8608', 'Moexipril', '1995', '26', []),
#  ('8609', 'Lisinopril', '1987', '34', []),
#  ('8612', 'Perindopril', '1988', '33', []),
#  ('8614', 'Quinapril', '1989', '32', []),
#  ('8621', 'Rescinnamine', '1956', '65', []),
#  ('8622', 'Captopril', '1980', '41', []),
#  ('8629', 'Cilazapril', '1990', '31', []),
#  ('8630', 'Spirapril', '1994', '27', []),
#  ('8634', 'Temocapril', '1994', '27', []),
#  ('8638', 'Doxycycline', '1967', '54', []),
#  ('8639', 'Lymecycline', '1963', '58', []),
#  ('8640', 'Framycetin', '1966', '55', []),
#  ('8642', 'Amikacin', '1976', '45', []),
#  ('8644', 'Oxytetracycline', '1950', '71', []),
#  ('8645', 'Demeclocycline', '1959', '62', []),
#  ('8646', 'Tobramycin', '1974', '47', []),
#  ('8647', 'Tetracycline', '1978', '43', []),
#  ('8648', 'Spectinomycin', '1971', '50', []),
#  ('8649', 'Methacycline', '1963', '58', []),
#  ('8650', 'Netilmicin', '1980', '41', []),
#  ('8651', 'Neomycin', '1951', '70', []),
#  ('8652', 'Minocycline', '1971', '50', []),
#  ('8654', 'Streptomycin', '1946', '75', []),
#  ('8655', 'Kanamycin', '1958', '63', []),
#  ('8656', 'Rolitetracycline', '1959', '62', []),
#  ('8658', 'Paromomycin', '1960', '61', []),
#  ('8659', 'Arbekacin', '1990', '31', []),
#  ('8593', 'Amsacrine', '1983', '38', []),
#  ('8636', 'Vindesine', '1980', '41', []),
#  ('8637', 'Paclitaxel', '1992', '29', []),
#  ('8661', 'Dexrazoxane', '1995', '26', []),
#  ('8662', 'Valrubicin', '1998', '23', []),
#  ('8663', 'Teniposide', '1984', '37', []),
#  ('8664', 'Enoxacin', '1991', '30', []),
#  ('8665', 'Pefloxacin', '1985', '36', []),
#  ('8666', 'Ciprofloxacin', '1986', '35', []),
#  ('8667', 'Daunorubicin', '1968', '53', []),
#  ('8668', 'Etoposide', '1981', '40', []),
#  ('8669', 'Doxorubicin', '1971', '50', []),
#  ('8670', 'Norfloxacin', '1983', '38', []),
#  ('8671', 'Levofloxacin', '1993', '28', []),
#  ('8672', 'Idarubicin', '1990', '31', []),
#  ('8673', 'Podofilox', '1820', '201', []),
#  ('8674', 'Mitoxantrone', '1984', '37', []),
#  ('8675', 'Sparfloxacin', '1993', '28', []),
#  ('8676', 'Fleroxacin', '1992', '29', []),
#  ('8698', 'Moxifloxacin', '1999', '22', []),
#  ('8700', 'Grepafloxacin', '1997', '24', []),
#  ('8701', 'Epirubicin', '1999', '22', []),
#  ('8702', 'Vincristine', '1963', '58', []),
#  ('8704', 'Irinotecan', '1994', '27', []),
#  ('8705', 'Lomefloxacin', '1989', '32', []),
#  ('8706', 'Topotecan', '1996', '25', []),
#  ('8707', 'Gatifloxacin', '1999', '22', []),
#  ('8708', 'Ofloxacin', '1985', '36', []),
#  ('8709', 'Colchicine', '1961', '60', []),
#  ('8710', 'Temafloxacin', '1992', '29', []),
#  ('8711', 'Sodium stibogluconate', '1940', '81', []),
#  ('8712', 'Besifloxacin', '2009', '12', []),
#  ('8766', 'Cinoxacin', '1979', '42', []),
#  ('8767', 'Gemifloxacin', '2003', '18', []),
#  ('7868', 'Bethanidine', '1981', '40', []),
#  ('7870', 'Glimepiride', '1995', '26', []),
#  ('7922', 'Acetohexamide', '1963', '58', []),
#  ('8055', 'Glyburide', '1971', '50', []),
#  ('8173', 'Probucol', '1977', '44', []),
#  ('8448', 'Tolbutamide', '1956', '65', []),
#  ('8465', 'Crofelemer', '2012', '9', []),
#  ('8595', 'Troglitazone', '1997', '24', []),
#  ('8598', 'Rosiglitazone', '1999', '22', []),
#  ('8603', 'Amiloride', '1971', '50', []),
#  ('8605', 'Clofibrate', '1963', '58', []),
#  ('8607', 'Chlorpropamide', '1958', '63', []),
#  ('8610', 'Nateglinide', '2000', '21', []),
#  ('8616', 'Repaglinide', '1998', '23', []),
#  ('8617', 'Fenofibrate', '1975', '46', []),
#  ('8619', 'Glipizide', '1971', '50', []),
#  ('8625', 'Gemfibrozil', '1982', '39', []),
#  ('8626', 'Gliquidone', '1975', '46', []),
#  ('8627', 'Mitiglinide', '2004', '17', []),
#  ('8631', 'Bezafibrate', '1977', '44', []),
#  ('8643', 'Lenalidomide', '2005', '16', []),
#  ('8678', 'Valsartan', '1996', '25', []),
#  ('8679', 'Olmesartan', '2002', '19', []),
#  ('8680', 'Celecoxib', '1999', '22', []),
#  ('8681', 'Losartan', '1994', '27', []),
#  ('8682', 'Candesartan', '1997', '24', []),
#  ('8683', 'Eprosartan', '1997', '24', []),
#  ('8684', 'Telmisartan', '1999', '22', []),
#  ('8685', 'Auranofin', '1982', '39', []),
#  ('8686', 'Irbesartan', '1997', '24', []),
#  ('8687', 'Ibuprofen', '1969', '52', []),
#  ('8688', 'Pioglitazone', '1999', '22', []),
#  ('8697', 'Azilsartan medoxomil', '2011', '10', []),
#  ('8713', 'Valdecoxib', '2001', '20', []),
#  ('8715', 'Icosapent', '2004', '17', []),
#  ('8716', 'Masoprocol', '1992', '29', []),
#  ('8717', 'Aminosalicylic Acid', '1948', '73', []),
#  ('8718', 'Mesalazine', '1988', '33', []),
#  ('8719', 'Acetaminophen', '1886', '135', []),
#  ('8720', 'Indomethacin', '1963', '58', []),
#  ('8721', 'Nabumetone', '1994', '27', []),
#  ('8722', 'Ketorolac', '1989', '32', []),
#  ('8723', 'Tenoxicam', '1987', '34', []),
#  ('8725', 'Rofecoxib', '1999', '22', []),
#  ('8726', 'Piroxicam', '1979', '42', []),
#  ('8727', 'Fenoprofen', '1974', '47', []),
#  ('8728', 'Diclofenac', '1974', '47', []),
#  ('8729', 'Sulindac', '1976', '45', []),
#  ('8730', 'Diethylcarbamazine', '1949', '72', []),
#  ('8731', 'Flurbiprofen', '1987', '34', []),
#  ('8732', 'Zileuton', '1996', '25', []),
#  ('8733', 'Etodolac', '1985', '36', []),
#  ('8734', 'Mefenamic acid', '1963', '58', []),
#  ('8735', 'Naproxen', '1973', '48', []),
#  ('8736', 'Sulfasalazine', '1950', '71', []),
#  ('8737', 'Phenylbutazone', '1952', '69', []),
#  ('8738', 'Meloxicam', '1996', '25', []),
#  ('8739', 'Carprofen', '1981', '40', []),
#  ('8740', 'Diflunisal', '1978', '43', []),
#  ('8741', 'Suprofen', '1988', '33', []),
#  ('8742', 'Salicylic acid', '1875', '146', []),
#  ('8743', 'Meclofenamic acid', '1980', '41', []),
#  ('8744', 'Acetylsalicylic acid', '1899', '122', []),
#  ('8745', 'Bromfenac', '1997', '24', []),
#  ('8746', 'Oxaprozin', '1983', '38', []),
#  ('8747', 'Ketoprofen', '1973', '48', []),
#  ('8748', 'Balsalazide', '2000', '21', []),
#  ('8749', 'Lumiracoxib', '2003', '18', []),
#  ('8750', 'Magnesium salicylate', '1979', '42', []),
#  ('8751', 'Salicylate-sodium', '1875', '146', []),
#  ('8754', 'Antrafenine', '1977', '44', []),
#  ('8755', 'Antipyrine', '1885', '136', []),
#  ('8756', 'Tiaprofenic acid', '1975', '46', []),
#  ('8757', 'Etoricoxib', '2002', '19', []),
#  ('8759', 'Resveratrol', '2015', '6', []),
#  ('8760', 'Niflumic Acid', '1968', '53', []),
#  ('8761', 'Nimesulide', '1985', '36', []),
#  ('8762', 'Acetylcysteine', '1968', '53', []),
#  ('8763', 'Lornoxicam', '1997', '24', []),
#  ('8764', 'Nepafenac', '2005', '16', []),
#  ('8765', 'Pomalidomide', '2013', '8', []),
#  ('', '', '', '', [])]

# %%
for db_version in DRUGBANK_DATABASES:
    print("Parsing Database {0}".format(db_version[1]))
    db = Database(db_version[2])
    db.parse()
    for item in output_data:
        drug_name = item[1]
        no_of_interactions = db.get_number_of_interactions(drug_name)
        item[4].append(no_of_interactions)
    del db
# Out:
# Parsing Database DB 3.0
# Parsing Database DB 4.1
# Parsing Database DB 4.2
# Parsing Database DB 4.3
# Parsing Database DB 4.5
# Parsing Database  DB 5.0
# Parsing Database DB 5.0.1
# Parsing Database DB 5.0.2
# Parsing Database DB 5.0.3
# Parsing Database DB 5.0.4
# Parsing Database DB 5.0.5
# Parsing Database DB 5.0.6
# Parsing Database DB 5.0.7
# Parsing Database DB 5.0.8
# Parsing Database DB 5.0.9
# Parsing Database DB 5.0.10
# Parsing Database DB 5.0.11
# Parsing Database DB 5.1.0
# Parsing Database DB 5.1.1
# Parsing Database DB 5.1.2
# Parsing Database DB 5.1.3
# Parsing Database DB 5.1.4
# Parsing Database DB 5.1.5
# Parsing Database DB 5.1.6
# Parsing Database DB 5.1.7
# Parsing Database DB 5.1.8

# %%
write_csv(CSV_DRUG_AGE_FILE_OUTPUT,output_data)
